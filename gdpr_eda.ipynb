# %%
# Modul import
import pandas as pd

# %%
# Data connection

df = pd.read_csv(r"enforcement_tracker_full_data.csv")
display(df.head())
display(df.tail())
# Out:
#         ETid Country                                    Authority  \
# 0  ETid-2534   SPAIN     Spanish Data Protection Authority (aepd)
# 1  ETid-2533   SPAIN     Spanish Data Protection Authority (aepd)
# 2  ETid-2532   SPAIN     Spanish Data Protection Authority (aepd)
# 3  ETid-2531   ITALY  Italian Data Protection Authority (Garante)
# 4  ETid-2530   SPAIN     Spanish Data Protection Authority (aepd)
#
#   Date of Decision   Fine [€]              Controller/Processor  \
# 0       2024-12-16     70,000    INTERURBANA DE AUTOBUSES, S.A.
# 1       2024-12-23     15,000  HSSERVICE LIZCON SOLUTIONS, S.L.
# 2       2023-12-27  6,500,000       THE PHONE HOUSE SPAIN, S.L.
# 3       2024-11-13  5,000,000                      Foodinho Srl
# 4       2024-11-22    220,000          CARTONAJES BAÑERES, S.A.
#
#                              Sector  \
# 0                        Employment
# 1             Industry and Commerce
# 2  Media, Telecoms and Broadcasting
# ...

# %%
# Changing colums names into uniform format

Date of Decision = Date_of_decision
Fine[€] = Fine
Controller/Processor = Controller_Processor
Quoted Art. = Quoted_Art
Direct URL = Direct_URL

# %%
# Checking for missing values

df.isna().sum()
# Out:
# ETid                    0
# Country                 0
# Authority               0
# Date of Decision        0
# Fine [€]                0
# Controller/Processor    0
# Sector                  0
# Quoted Art.             0
# Type                    0
# Summary                 0
# Source                  1
# Direct URL              0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# ETid                    0
# Country                 0
# Authority               0
# Date of Decision        0
# Fine [€]                0
# Controller/Processor    0
# Sector                  0
# Quoted Art.             0
# Type                    0
# Summary                 0
# Source                  1
# Direct URL              0
# dtype: int64

# %%
# Checking data types
df.dtypes
# Out:
# ETid                    object
# Country                 object
# Authority               object
# Date of Decision        object
# Fine [€]                object
# Controller/Processor    object
# Sector                  object
# Quoted Art.             object
# Type                    object
# Summary                 object
# Source                  object
# Direct URL              object
# dtype: object

# %%
# Changing data types

Country = category
Authority = category
Date_of_decision = date
Fine = float
Controller_Processor = category
Type = category
